# %%
import pandas as pd

df_vehicle_crashes = pd.read_parquet("../vehicle_crashes_cleaned.parquet")
df_vehicle_crashes_vehicle = pd.read_parquet("../vehicle_crashes_vehicle_cleaned.parquet")
df_vehicle_crashes_person = pd.read_parquet("../vehicle_crashes_person_cleaned.parquet")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df_vehicle_crashes = pd.read_parquet("../vehicle_crashes_cleaned.parquet")
#       4 df_vehicle_crashes_vehicle = pd.read_parquet("../vehicle_crashes_vehicle_cleaned.parquet")
#       5 df_vehicle_crashes_person = pd.read_parquet("../vehicle_crashes_person_cleaned.parquet")
#
# File c:\Users\gisle\anaconda3\envs\compTools\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
# ...

# %%
df_vehicle_crashes.head(5)
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  2021-09-11       2:39       NaN       NaN       NaN        NaN
# 1  2022-03-26      11:45       NaN       NaN       NaN        NaN
# 2  2023-11-01       1:29  BROOKLYN   11230.0  40.62179 -73.970024
# 3  2022-06-29       6:55       NaN       NaN       NaN        NaN
# 4  2022-09-21      13:21       NaN       NaN       NaN        NaN
#
#             ON STREET NAME  NUMBER OF PERSONS INJURED  \
# 0    WHITESTONE EXPRESSWAY                        2.0
# 1  QUEENSBORO BRIDGE UPPER                        1.0
# 2            OCEAN PARKWAY                        1.0
# 3       THROGS NECK BRIDGE                        0.0
# 4          BROOKLYN BRIDGE                        0.0
#
#    NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  ...  \
# 0                       0.0                              0  ...
# 1                       0.0                              0  ...
# ...

# %%
df_vehicle_crashes_vehicle.head(5)
# Out:
#    COLLISION_ID  CRASH_DATE CRASH_TIME                         VEHICLE_TYPE  \
# 0        100201  09/07/2012       9:03                    PASSENGER VEHICLE
# 1       4213082  09/23/2019       8:15  Station Wagon/Sport Utility Vehicle
# 2       3307608  10/02/2015      17:18                                 TAXI
# 3       3308693  10/04/2015      20:34                    PASSENGER VEHICLE
# 4        297666  04/25/2013      21:15                    PASSENGER VEHICLE
#
#     VEHICLE_MAKE VEHICLE_MODEL  VEHICLE_YEAR TRAVEL_DIRECTION  \
# 0            NaN           NaN           NaN              NaN
# 1  TOYT -CAR/SUV           NaN        2002.0            North
# 2            NaN           NaN           NaN              NaN
# 3            NaN           NaN           NaN              NaN
# 4            NaN           NaN           NaN              NaN
#
#    VEHICLE_OCCUPANTS DRIVER_SEX DRIVER_LICENSE_STATUS             PRE_CRASH  \
# ...

# %%
df_vehicle_crashes_person.head(5)
# Out:
#    COLLISION_ID  CRASH_DATE CRASH_TIME PERSON_TYPE PERSON_INJURY  PERSON_AGE  \
# 0       4229554  10/26/2019       9:43    Occupant   Unspecified         NaN
# 1       4230587  10/25/2019      15:15    Occupant   Unspecified        33.0
# 2       4230550  10/26/2019      17:55    Occupant   Unspecified        55.0
# 3       3565527  11/21/2016      13:05    Occupant   Unspecified         NaN
# 4       4231168  10/25/2019      11:16    Occupant   Unspecified         7.0
#
#       EJECTION                                POSITION_IN_VEHICLE  \
# 0          NaN                                                NaN
# 1  Not Ejected  Front passenger, if two or more persons, inclu...
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4  Not Ejected  Right rear passenger or motorcycle sidecar pas...
#
#      SAFETY_EQUIPMENT PED_LOCATION PED_ACTION CONTRIBUTING_FACTOR_1  \
# ...
