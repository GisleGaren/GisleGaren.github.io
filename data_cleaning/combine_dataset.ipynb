# %%
import pandas as pd

df_vehicle_crashes = pd.read_parquet("../optimized_datasets/vehicle_crashes_cleaned.parquet")
df_vehicle_crashes_vehicle = pd.read_parquet("../optimized_datasets/vehicle_crashes_vehicle_cleaned.parquet")
df_vehicle_crashes_person = pd.read_parquet("../optimized_datasets/vehicle_crashes_person_cleaned.parquet")

# %%
df_vehicle_crashes.head(5)
# Out:
#   CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0 2021-09-11       2:39       NaN      <NA>       NaN        NaN
# 1 2022-03-26      11:45       NaN      <NA>       NaN        NaN
# 2 2023-11-01       1:29  BROOKLYN     11230  40.62179 -73.970024
# 3 2022-06-29       6:55       NaN      <NA>       NaN        NaN
# 4 2022-09-21      13:21       NaN      <NA>       NaN        NaN
#
#             ON STREET NAME  NUMBER OF PERSONS INJURED  \
# 0    WHITESTONE EXPRESSWAY                        2.0
# 1  QUEENSBORO BRIDGE UPPER                        1.0
# 2            OCEAN PARKWAY                        1.0
# 3       THROGS NECK BRIDGE                        0.0
# 4          BROOKLYN BRIDGE                        0.0
#
#    NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  ...  \
# 0                       0.0                              0  ...
# 1                       0.0                              0  ...
# ...

# %%
df_vehicle_crashes_vehicle.head(5)
# Out:
#    COLLISION_ID CRASH_DATE CRASH_TIME                         VEHICLE_TYPE  \
# 0        100201 2012-09-07       9:03                    PASSENGER VEHICLE
# 1       4213082 2019-09-23       8:15  Station Wagon/Sport Utility Vehicle
# 2       3307608 2015-10-02      17:18                                 TAXI
# 3       3308693 2015-10-04      20:34                    PASSENGER VEHICLE
# 4        297666 2013-04-25      21:15                    PASSENGER VEHICLE
#
#     VEHICLE_MAKE VEHICLE_MODEL  VEHICLE_YEAR TRAVEL_DIRECTION  \
# 0            NaN           NaN           NaN              NaN
# 1  TOYT -CAR/SUV           NaN        2002.0            North
# 2            NaN           NaN           NaN              NaN
# 3            NaN           NaN           NaN              NaN
# 4            NaN           NaN           NaN              NaN
#
#    VEHICLE_OCCUPANTS DRIVER_SEX DRIVER_LICENSE_STATUS             PRE_CRASH  \
# ...

# %%
df_vehicle_crashes_person.head(5)
# Out:
#    COLLISION_ID CRASH_DATE CRASH_TIME PERSON_TYPE PERSON_INJURY  PERSON_AGE  \
# 0       4229554 2019-10-26       9:43    Occupant   Unspecified         NaN
# 1       4230587 2019-10-25      15:15    Occupant   Unspecified        33.0
# 2       4230550 2019-10-26      17:55    Occupant   Unspecified        55.0
# 3       3565527 2016-11-21      13:05    Occupant   Unspecified         NaN
# 4       4231168 2019-10-25      11:16    Occupant   Unspecified         7.0
#
#       EJECTION                                POSITION_IN_VEHICLE  \
# 0          NaN                                                NaN
# 1  Not Ejected  Front passenger, if two or more persons, inclu...
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4  Not Ejected  Right rear passenger or motorcycle sidecar pas...
#
#      SAFETY_EQUIPMENT PED_LOCATION PED_ACTION CONTRIBUTING_FACTOR_1  \
# ...

# %%
# count the COLLISION_ID that has the highest count in df_vehicle_crashes_person
df_vehicle_crashes_person['COLLISION_ID'].value_counts().head(5)
# Out:
# COLLISION_ID
# 3963775    77
# 4691158    71
# 3591272    66
# 3539636    65
# 3504309    64
# Name: count, dtype: int64
